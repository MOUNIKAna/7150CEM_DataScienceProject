# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Crime_Data_from_2020_to_Present.csv")

# %%
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# ...

# %%
df.tail()
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 825207  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 825208  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 825209  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 825210  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 825211  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 825207    16     Foothill         1663         2     740
# 825208    16     Foothill         1602         1     230
# 825209    12  77th Street         1239         1     230
# 825210     1      Central          154         1     352
# 825211     9     Van Nuys          914         2     745
#
#                                               Crm Cd Desc  ... Status  \
# 825207  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...

# %%
df.shape
# Out:
# (825212, 28)

# %%
df.columns.tolist()
# Out:
# ['DR_NO',
#  'Date Rptd',
#  'DATE OCC',
#  'TIME OCC',
#  'AREA',
#  'AREA NAME',
#  'Rpt Dist No',
#  'Part 1-2',
#  'Crm Cd',
#  'Crm Cd Desc',
#  'Mocodes',
#  'Vict Age',
#  'Vict Sex',
#  'Vict Descent',
#  'Premis Cd',
#  'Premis Desc',
#  'Weapon Used Cd',
#  'Weapon Desc',
#  'Status',
#  'Status Desc',
#  'Crm Cd 1',
#  'Crm Cd 2',
#  'Crm Cd 3',
#  'Crm Cd 4',
#  'LOCATION',
#  'Cross Street',
#  'LAT',
#  'LON']

# %%
print("\nMissing values:", df.isnull().sum().values.sum())
# Out:
# Missing values: 4512890

# %%
df.nunique()
# Out:
# DR_NO             825212
# Date Rptd           1392
# DATE OCC            1392
# TIME OCC            1439
# AREA                  21
# AREA NAME             21
# Rpt Dist No         1206
# Part 1-2               2
# Crm Cd               138
# Crm Cd Desc          138
# Mocodes           275294
# Vict Age             103
# Vict Sex               5
# Vict Descent          20
# Premis Cd            313
# Premis Desc          306
# Weapon Used Cd        79
# Weapon Desc           79
# Status                 6
# Status Desc            6
# Crm Cd 1             140
# Crm Cd 2             123
# Crm Cd 3              37
# Crm Cd 4               6
# LOCATION           63802
# Cross Street        9710
# LAT                 5402
# LON                 4970
# dtype: int64

# %%
df.isnull().any()
# Out:
# DR_NO             False
# Date Rptd         False
# DATE OCC          False
# TIME OCC          False
# AREA              False
# AREA NAME         False
# Rpt Dist No       False
# Part 1-2          False
# Crm Cd            False
# Crm Cd Desc       False
# Mocodes            True
# Vict Age          False
# Vict Sex           True
# Vict Descent       True
# Premis Cd          True
# Premis Desc        True
# Weapon Used Cd     True
# Weapon Desc        True
# Status            False
# Status Desc       False
# Crm Cd 1           True
# Crm Cd 2           True
# Crm Cd 3           True
# Crm Cd 4           True
# LOCATION          False
# Cross Street       True
# LAT               False
# LON               False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           114148
# Vict Age               0
# Vict Sex          108529
# Vict Descent      108537
# Premis Cd             10
# Premis Desc          488
# Weapon Used Cd    537498
# Weapon Desc       537498
# Status                 0
# Status Desc            0
# Crm Cd 1              10
# Crm Cd 2          764505
# Crm Cd 3          823173
# Crm Cd 4          825151
# LOCATION               0
# Cross Street      693343
# LAT                    0
# LON                    0
# dtype: int64

# %%
df.dtypes
# Out:
# DR_NO               int64
# Date Rptd          object
# DATE OCC           object
# TIME OCC            int64
# AREA                int64
# AREA NAME          object
# Rpt Dist No         int64
# Part 1-2            int64
# Crm Cd              int64
# Crm Cd Desc        object
# Mocodes            object
# Vict Age            int64
# Vict Sex           object
# Vict Descent       object
# Premis Cd         float64
# Premis Desc        object
# Weapon Used Cd    float64
# Weapon Desc        object
# Status             object
# Status Desc        object
# Crm Cd 1          float64
# Crm Cd 2          float64
# Crm Cd 3          float64
# Crm Cd 4          float64
# LOCATION           object
# Cross Street       object
# LAT               float64
# LON               float64
# dtype: object

# %% [markdown]
# Data Pre-Processing

# %%
# Drop Columns that are not required
df.drop(['DR_NO', 'Date Rptd', 'Rpt Dist No' , 'Part 1-2', 'Mocodes', 'Crm Cd 1', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Cross Street', 'LOCATION'], axis=1, inplace=True)

# %%
df
# Out:
#                       DATE OCC  TIME OCC  AREA    AREA NAME  Crm Cd  \
# 0       01/08/2020 12:00:00 AM      2230     3    Southwest     624
# 1       01/01/2020 12:00:00 AM       330     1      Central     624
# 2       02/13/2020 12:00:00 AM      1200     1      Central     845
# 3       01/01/2020 12:00:00 AM      1730    15  N Hollywood     745
# 4       01/01/2020 12:00:00 AM       415    19      Mission     740
# ...                        ...       ...   ...          ...     ...
# 825207  01/26/2023 12:00:00 AM      1800    16     Foothill     740
# 825208  03/22/2023 12:00:00 AM      1000    16     Foothill     230
# 825209  04/12/2023 12:00:00 AM      1630    12  77th Street     230
# 825210  07/01/2023 12:00:00 AM         1     1      Central     352
# 825211  03/05/2023 12:00:00 AM       900     9     Van Nuys     745
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# ...

# %%
df.isnull().sum()
# Out:
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Crm Cd                 0
# Crm Cd Desc            0
# Vict Age               0
# Vict Sex          108529
# Vict Descent      108537
# Premis Cd             10
# Premis Desc          488
# Weapon Used Cd    537498
# Weapon Desc       537498
# Status                 0
# Status Desc            0
# LAT                    0
# LON                    0
# dtype: int64

# %%
#take care of missng values by dropping rows with missing values
df.dropna(axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                       DATE OCC  TIME OCC  AREA    AREA NAME  Crm Cd  \
# 0       01/08/2020 12:00:00 AM      2230     3    Southwest     624
# 1       01/01/2020 12:00:00 AM       330     1      Central     624
# 2       01/01/2020 12:00:00 AM        30     1      Central     121
# 3       01/04/2020 12:00:00 AM      2200     1      Central     330
# 4       01/05/2020 12:00:00 AM       955     1      Central     930
# ...                        ...       ...   ...          ...     ...
# 287394  07/24/2023 12:00:00 AM      1400     6    Hollywood     210
# 287395  09/20/2023 12:00:00 AM      1915     9     Van Nuys     624
# 287396  10/20/2023 12:00:00 AM      2315     6    Hollywood     930
# 287397  03/22/2023 12:00:00 AM      1000    16     Foothill     230
# 287398  04/12/2023 12:00:00 AM      1630    12  77th Street     230
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 0                             BATTERY - SIMPLE ASSAULT        36        F
# ...

# %%
#create date-time features from DATE OCC column
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])
df['YEAR OCC'] = df['DATE OCC'].dt.year
df['MONTH OCC'] = df['DATE OCC'].dt.month
df['DAY OCC'] = df['DATE OCC'].dt.day

# %%
df
# Out:
#          DATE OCC  TIME OCC  AREA    AREA NAME  Crm Cd  \
# 0      2020-01-08      2230     3    Southwest     624
# 1      2020-01-01       330     1      Central     624
# 2      2020-01-01        30     1      Central     121
# 3      2020-01-04      2200     1      Central     330
# 4      2020-01-05       955     1      Central     930
# ...           ...       ...   ...          ...     ...
# 287394 2023-07-24      1400     6    Hollywood     210
# 287395 2023-09-20      1915     9     Van Nuys     624
# 287396 2023-10-20      2315     6    Hollywood     930
# 287397 2023-03-22      1000    16     Foothill     230
# 287398 2023-04-12      1630    12  77th Street     230
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 0                             BATTERY - SIMPLE ASSAULT        36        F
# 1                             BATTERY - SIMPLE ASSAULT        25        M
# 2                                       RAPE, FORCIBLE        25        F
# ...

# %%
df_desc = df[['Crm Cd Desc', 'Premis Desc', 'Weapon Desc', 'Status Desc']]
df = df[['YEAR OCC', 'MONTH OCC', 'DAY OCC', 'TIME OCC', 'AREA', 'AREA NAME', 'Crm Cd', 'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Weapon Used Cd', 'Status']]

# %%
df
# Out:
#         YEAR OCC  MONTH OCC  DAY OCC  TIME OCC  AREA    AREA NAME  Crm Cd  \
# 0           2020          1        8      2230     3    Southwest     624
# 1           2020          1        1       330     1      Central     624
# 2           2020          1        1        30     1      Central     121
# 3           2020          1        4      2200     1      Central     330
# 4           2020          1        5       955     1      Central     930
# ...          ...        ...      ...       ...   ...          ...     ...
# 287394      2023          7       24      1400     6    Hollywood     210
# 287395      2023          9       20      1915     9     Van Nuys     624
# 287396      2023         10       20      2315     6    Hollywood     930
# 287397      2023          3       22      1000    16     Foothill     230
# 287398      2023          4       12      1630    12  77th Street     230
#
#         Vict Age Vict Sex Vict Descent  Premis Cd  Weapon Used Cd Status
# ...

# %%
df_dist = df.iloc[:, [1, 2, 3, 4, 6, 7, 10, 11]]

# %%
fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))

for i, feature in enumerate(df_dist.columns):
    row = int(i/4)
    col = i%4
    sns.distplot(df_dist.iloc[:, i], ax=axs[row][col])

plt.suptitle('Feature Distribution')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
Vict_Age_0 = df[df['Vict Age'] == 0].index
df.drop(Vict_Age_0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#         YEAR OCC  MONTH OCC  DAY OCC  TIME OCC  AREA    AREA NAME  Crm Cd  \
# 0           2020          1        8      2230     3    Southwest     624
# 1           2020          1        1       330     1      Central     624
# 2           2020          1        1        30     1      Central     121
# 3           2020          1        4      2200     1      Central     330
# 4           2020          1        5       955     1      Central     930
# ...          ...        ...      ...       ...   ...          ...     ...
# 264665      2023          7       24      1400     6    Hollywood     210
# 264666      2023          9       20      1915     9     Van Nuys     624
# 264667      2023         10       20      2315     6    Hollywood     930
# 264668      2023          3       22      1000    16     Foothill     230
# 264669      2023          4       12      1630    12  77th Street     230
#
#         Vict Age Vict Sex Vict Descent  Premis Cd  Weapon Used Cd Status
# ...

# %%
Crm_Cd_Log = np.log1p(df['Crm Cd'])
Premis_Cd_Log = np.log1p(df['Premis Cd'])
Weapon_Used_Cd_Log = np.log1p(df['Weapon Used Cd'])

# %%
df.insert(7, 'Crm Cd Log', Crm_Cd_Log)
df.insert(12, 'Premis Cd Log', Premis_Cd_Log)
df.insert(14, 'Weapon Used Cd Log', Weapon_Used_Cd_Log)

# %%
df_dist_log = df[['Crm Cd Log', 'Premis Cd Log', 'Weapon Used Cd Log']]
fig, axs = plt.subplots(ncols=3, figsize=(15, 5))

for i, feature in enumerate(df_dist_log.columns):
    col = i%3
    sns.distplot(df_dist_log.iloc[:, i], ax=axs[col])

plt.suptitle('Log Converted Features Distribution')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
df
# Out:
#         YEAR OCC  MONTH OCC  DAY OCC  TIME OCC  AREA    AREA NAME  Crm Cd  \
# 0           2020          1        8      2230     3    Southwest     624
# 1           2020          1        1       330     1      Central     624
# 2           2020          1        1        30     1      Central     121
# 3           2020          1        4      2200     1      Central     330
# 4           2020          1        5       955     1      Central     930
# ...          ...        ...      ...       ...   ...          ...     ...
# 264665      2023          7       24      1400     6    Hollywood     210
# 264666      2023          9       20      1915     9     Van Nuys     624
# 264667      2023         10       20      2315     6    Hollywood     930
# 264668      2023          3       22      1000    16     Foothill     230
# 264669      2023          4       12      1630    12  77th Street     230
#
#         Crm Cd Log  Vict Age Vict Sex Vict Descent  Premis Cd  Premis Cd Log  \
# ...

# %%
df = df.astype({'YEAR OCC': 'int64', 'MONTH OCC': 'int64', 'DAY OCC': 'int64'})

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64'])
plt.figure(figsize=(10, 8))
plt.title('Correlation')
sns.heatmap(numeric_columns.corr(), annot=True, linewidths=.5, cmap="YlGnBu")
# Out:
# <Axes: title={'center': 'Correlation'}>

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder
df_scaled = df.copy()
excluded_features = ['MONTH OCC', 'AREA NAME', 'Vict Sex', 'Vict Descent', 'Status'] # features on this list will not be scaled
selected_features = np.array(df.drop(excluded_features, axis=1, inplace=False).columns).reshape(-1, 1)

for feature in selected_features:
    scaler = MinMaxScaler()
    scaler.fit(df_scaled[feature])
    df_scaled[feature] = scaler.transform(df_scaled[feature])

# %%
df_train = df.drop(['AREA NAME', 'Vict Descent', 'Status'] ,axis=1, inplace=False)
df_train = pd.get_dummies(df_train)

# %%
df_train
# Out:
#         YEAR OCC  MONTH OCC  DAY OCC  TIME OCC  AREA  Crm Cd  Crm Cd Log  \
# 0           2020          1        8      2230     3     624    6.437752
# 1           2020          1        1       330     1     624    6.437752
# 2           2020          1        1        30     1     121    4.804021
# 3           2020          1        4      2200     1     330    5.802118
# 4           2020          1        5       955     1     930    6.836259
# ...          ...        ...      ...       ...   ...     ...         ...
# 264665      2023          7       24      1400     6     210    5.351858
# 264666      2023          9       20      1915     9     624    6.437752
# 264667      2023         10       20      2315     6     930    6.836259
# 264668      2023          3       22      1000    16     230    5.442418
# 264669      2023          4       12      1630    12     230    5.442418
#
#         Vict Age  Premis Cd  Premis Cd Log  Weapon Used Cd  \
# ...

# %%
features = np.array(df_train.columns).reshape(-1, 1)

for feature in features:
    scaler = MinMaxScaler()
    scaler.fit(df_train[feature])
    df_train[feature] = scaler.transform(df_train[feature])

# %%
train_features = df[['YEAR OCC', 'MONTH OCC', 'DAY OCC', 'TIME OCC', 'AREA', 'Vict Age', 'Premis Cd Log', 'Weapon Used Cd Log']]
train_label = df['Crm Cd Log'].astype(int)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(train_features, train_label, test_size=0.2, random_state=11)

# %%
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, roc_auc_score
from sklearn.linear_model import LogisticRegression

# %%
lr_reg = LogisticRegression(solver='liblinear')
lr_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
lr_preds = lr_reg.predict(X_test)
lr_preds_proba = lr_reg.predict_proba(X_test)
lr_mse = mean_squared_error(y_test, lr_preds)
lr_rmse = np.sqrt(lr_mse)
lr_r2 = abs(r2_score(y_test, lr_preds))
lr_acc = accuracy_score(y_test, lr_preds)
lr_roc_auc = roc_auc_score(y_test, lr_preds_proba, multi_class='ovr')

# %%
print('Measuring the performance : MSE : {0:.3f}'.format(lr_mse))
print('Measuring the performance : RMSE : {0:.3f}'.format(lr_rmse))
print('Variance Score : {0:.3f}'.format(lr_r2))
print('Accuracy Score : {0:.3f}'.format(lr_acc))
print('ROC_AUC Score : {0:.3f}'.format(lr_roc_auc))
# Out:
# Measuring the performance : MSE : 0.316
# Measuring the performance : RMSE : 0.562
# Variance Score : 0.152
# Accuracy Score : 0.722
# ROC_AUC Score : 0.715

# %%
lr_classification_report = classification_report(y_test, lr_preds)
print("Classification Report for Logistic Regression:\n", lr_classification_report)
# Out:
# Classification Report for Logistic Regression:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00       931
#            5       0.75      0.39      0.51     18997
#            6       0.71      0.93      0.81     33006
#
#     accuracy                           0.72     52934
#    macro avg       0.49      0.44      0.44     52934
# weighted avg       0.72      0.72      0.69     52934

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)

# %%
import xgboost as xgb

# %%
class_mapping = {4: 0, 5: 1, 6: 2}
y_train_mapped = [class_mapping[label] for label in y_train]
y_test_mapped = [class_mapping[label] for label in y_test]

# %%
# To improve the speed of model performance
xgb_model = xgb.XGBClassifier(n_estimators=1000, learning_rate=0.01)
xgb_model.fit(X_train, y_train_mapped)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
xgb_preds = xgb_model.predict(X_test)
xgb_preds_proba = xgb_model.predict_proba(X_test)

# %%
xgb_mse = mean_squared_error(y_test_mapped, xgb_preds)
xgb_rmse = np.sqrt(xgb_mse)
xgb_r2 = r2_score(y_test_mapped, xgb_preds)
xgb_acc = accuracy_score(y_test_mapped, xgb_preds)
xgb_roc_auc = roc_auc_score(y_test_mapped, xgb_preds_proba, multi_class='ovr')

# %%
print('MSE : {0:.3f}'.format(xgb_mse))
print('RMSE : {0:.3f}'.format(xgb_rmse))
print('Variance Score : {0:.3f}'.format(xgb_r2))
print('Accuracy Score : {0:.3f}'.format(xgb_acc))
print('ROC_AUC Score : {0:.3f}'.format(xgb_roc_auc))
# Out:
# MSE : 0.261
# RMSE : 0.511
# Variance Score : 0.049
# Accuracy Score : 0.776
# ROC_AUC Score : 0.820

# %%
xgb_classification_report = classification_report(y_test_mapped, xgb_preds)
print("Classification Report for XGBoost:\n", xgb_classification_report)
# Out:
# Classification Report for XGBoost:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       931
#            1       0.73      0.64      0.68     18997
#            2       0.80      0.87      0.83     33006
#
#     accuracy                           0.78     52934
#    macro avg       0.51      0.51      0.51     52934
# weighted avg       0.76      0.78      0.76     52934

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_model = GradientBoostingClassifier()
gb_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
gb_preds = gb_model.predict(X_test)
gb_preds_proba = gb_model.predict_proba(X_test)

# %%
gb_mse = mean_squared_error(y_test, gb_preds)
gb_rmse = np.sqrt(gb_mse)
gb_r2 = r2_score(y_test, gb_preds)
gb_acc = accuracy_score(y_test, gb_preds)
gb_roc_auc = roc_auc_score(y_test, gb_preds_proba, multi_class='ovr')

# %%
print('MSE : {0:.3f}'.format(gb_mse))
print('RMSE : {0:.3f}'.format(gb_rmse))
print('Variance Score : {0:.3f}'.format(gb_r2))
print('Accuracy Score : {0:.3f}'.format(gb_acc))
print('ROC_AUC Score : {0:.3f}'.format(gb_roc_auc))
# Out:
# MSE : 0.265
# RMSE : 0.514
# Variance Score : 0.034
# Accuracy Score : 0.771
# ROC_AUC Score : 0.813

# %%
gb_classification_report = classification_report(y_test, gb_preds)
print("Classification Report for GradientBoosting:\n", gb_classification_report)
# Out:
# Classification Report for GradientBoosting:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00       931
#            5       0.73      0.63      0.68     18997
#            6       0.79      0.87      0.83     33006
#
#     accuracy                           0.77     52934
#    macro avg       0.51      0.50      0.50     52934
# weighted avg       0.75      0.77      0.76     52934

# %%
results = {
    'Model': ['Logistic Regression', 'XGBClassifier', 'GBCLassifier'],
    'MSE': [lr_mse, xgb_mse, gb_mse],
    'RMSE': [lr_rmse, xgb_rmse, gb_rmse],
    'R^2': [lr_r2, xgb_r2, gb_r2],
    'Accuracy': [lr_acc, xgb_acc, gb_acc],
    'ROC AUC': [lr_roc_auc, xgb_roc_auc, gb_roc_auc]
}

results_df = pd.DataFrame(results)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))
melted_df = pd.melt(results_df, id_vars=['Model'], var_name='Metric', value_name='Value')
sns.barplot(x='Model', y='Value', hue='Metric', data=melted_df, palette="Set3")
plt.title('Comparison of Metrics for Multiple Models')
plt.ylabel('Value')
plt.legend(title='Metrics', loc='upper left')

ax = plt.gca()
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
sns.distplot(df['AREA'])
print("The mostly affected community : 77th Street")
# Out:
# The mostly affected community : 77th Street

# %%
sns.distplot(df['Vict Age'])
plt.title('Distribution of Vict Age')
print("People of 30s were most affected to crimes")
print("People of about 70s were less affted to crimes")
# Out:
# People of 30s were most affected to crimes
# People of about 70s were less affted to crimes
